# %% [markdown]
# # New Section

# %%
import pandas as pd
from langdetect import detect
import re
import nltk

from gensim.models import Word2Vec
from nltk.corpus import stopwords


nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
pip install langdetect

# %%
df = pd.read_csv('IndianFoodDatasetCSV.csv')
df.head()
# Out:
#    Srno                                         RecipeName  \
# 0     1                               Masala Karela Recipe
# 1     2  टमाटर पुलियोगरे रेसिपी - Spicy Tomato Rice (Re...
# 2     3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     5  आंध्रा स्टाइल आलम पचड़ी रेसिपी - Adrak Chutney ...
#
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                          Ingredients  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...
# 1  2-1/2 कप चावल - पका ले,3 टमाटर,3 छोटा चमच्च बी...
# 2  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...
# 3  500 grams Chicken,2 Onion - chopped,1 Tomato -...
# ...

# %%
# Removing all the rows which contain data in Hindi

text_column = 'Instructions'
# filtered_df = df[df.apply(lambda row: detect(row[text_column]) != 'hi', axis=1)]
# filtered_df.to_csv('InidanFoodDataFiltered.csv', index=False)

############## try2
# Define a regular expression pattern to match Hindi text
hindi_pattern = re.compile(r'[ॐ-ॿ]+')  # This pattern matches Hindi characters

# Function to check if a cell contains Hindi text
def contains_hindi(text):
    return bool(hindi_pattern.search(text))

# Filter the DataFrame to keep rows that don't contain Hindi text in the specified column
filtered_df = df[~df[text_column].apply(contains_hindi)]

# Save the filtered DataFrame back to a CSV file
filtered_df.to_csv('filtered_file.csv', index=False)

# %%
filtered_df.head()
# Out:
#    Srno                                         RecipeName  \
# 0     1                               Masala Karela Recipe
# 2     3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 5     6  Pudina Khara Pongal Recipe (Rice and Lentils C...
# 6     7         Udupi Style Ash Gourd Coconut Curry Recipe
#
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# 5  Pudina Khara Pongal Recipe (Rice and Lentils C...
# 6         Udupi Style Ash Gourd Coconut Curry Recipe
#
#                                          Ingredients  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...
# 2  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...
# 3  500 grams Chicken,2 Onion - chopped,1 Tomato -...
# 5  1 cup Rice - soaked for 20 minutes,1/2 cup Yel...
# ...

# %%
# df = filtered_df
df =  pd.read_csv('filtered_file.csv')
df.head()
# Out:
#    Srno                                         RecipeName  \
# 0     1                               Masala Karela Recipe
# 1     3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 2     4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 3     6  Pudina Khara Pongal Recipe (Rice and Lentils C...
# 4     7         Udupi Style Ash Gourd Coconut Curry Recipe
#
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 2  Gongura Chicken Curry Recipe - Andhra Style Go...
# 3  Pudina Khara Pongal Recipe (Rice and Lentils C...
# 4         Udupi Style Ash Gourd Coconut Curry Recipe
#
#                                          Ingredients  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...
# 1  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...
# 2  500 grams Chicken,2 Onion - chopped,1 Tomato -...
# 3  1 cup Rice - soaked for 20 minutes,1/2 cup Yel...
# ...

# %%
# Get the number of rows using the len() function
num_rows = len(df)

print("Number of rows in the DataFrame:", num_rows)
# Out:
# Number of rows in the DataFrame: 5662

# %%
#### -----DELETE-----------
# print("List of data from the specified column:", data_list)
# print(len(data_list))
# # # ######
# # # Preprocessing the data
# for i in range(0, len(data_list)):
#     text = re.sub(r'\[[0-9]*\]', ' ', data_list[i])
# #     text = re.sub(r'\s+', ' ', text)
# #     text = text.lower()
# #     text = re.sub(r'\d', ' ', text)
# #     text = re.sub(r'\s+', ' ', text)
#     data_list [i] = text  # Update the element in the list

# print("Processed list of data from the specified column:", data_list)
# # # # Preprocessing the data

# # # for i in range(0, len(data_list)):
# # #   text = re.sub(r'\[[0-9]*\]',' ',data_list[i])
# # #   text = re.sub(r'\s+',' ',text)
# # #   text = text.lower()
# # #   text = re.sub(r'\d',' ',text)
# # #   text = re.sub(r'\s+',' ',text)

# %%
# Extract the data from the specified column and create a list
data_list = df['Ingredients'].tolist()
print(type(data_list[0]))
# Out:
# <class 'str'>

# %%
# checking rows where string data not present
for i in range(0, len(data_list)):
  if not isinstance(data_list[i], str):
    print("Faulty", data_list[i])

# # checking rows with NaN values & Removing rows with Nan Values
# rows_with_nan = df[df.isna().any(axis=1)]
# print("Rows with NaN values:\n", rows_with_nan)

# df = df.dropna()

# checking rows with NaN values & Removing rows with Nan Values
for index, row in df.iterrows():
    if row.isna().any():
        print("Row {} contains NaN values.".format(index))
        df = df.drop(index)
# saving modified df to a new csv
df.to_csv('/content/filteredNaN.csv', index=False)
print(len(df))
# Out:
# Faulty nan
# Faulty nan
# Faulty nan
# Faulty nan
# Faulty nan
# Faulty nan
# Row 238 contains NaN values.
# Row 1046 contains NaN values.
# Row 1505 contains NaN values.
# Row 1521 contains NaN values.
# Row 4457 contains NaN values.
# Row 4627 contains NaN values.
# 5656

# %%
data_list = df['Ingredients'].tolist()
# checking rows where string data not present
for i in range(0, len(data_list)):
  if not isinstance(data_list[i], str):
    print("Faulty", data_list[i])

# %%
# ----Kshitij-----------------
# the below commented code is no longer required as all the list elements are string type
# for i in range(0, len(data_list)):
#   if isinstance(data_list[i], str):
#     text = re.sub(r'\[[0-9]*\]', ' ', data_list[i])
#     data_list[i] = text  # Update the element in the list

# %%
# Extract the data from the specified column and create a list
data_list = df['Ingredients'].tolist()
print(type(data_list[0]))

print("List of data from the specified column:", data_list[0])
print(len(data_list))

######################################
# # Preprocessing the data

allText = ""
for i in range(0, len(data_list)):
  allText += data_list[i]+' '

text = re.sub(r'\[[0-9]*\]', ' ', allText)
text = re.sub(r'\s+', ' ', text)
text = text.lower()
text = re.sub(r'\d', ' ', text)
text = re.sub(r'\s+', ' ', text)
# Remove characters like parentheses, backslash, forward slash, hyphen, and comma
text = re.sub(r'[\(\)\\/\-,]', ' ', text)

# Preparing the dataset
sentences = nltk.sent_tokenize(text)
sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

for i in range(len(sentences)):
  sentences[i] = [word for word in sentences[i] if word not in stopwords.words('english')]

print("Sentences: ")
print(sentences[0])
# Out:
# <class 'str'>
# List of data from the specified column: 6 Karela (Bitter Gourd/ Pavakkai) - deseeded,Salt - to taste,1 Onion - thinly sliced,3 tablespoon Gram flour (besan),2 teaspoons Turmeric powder (Haldi),1 tablespoon Red Chilli powder,2 teaspoons Cumin seeds (Jeera),1 tablespoon Coriander Powder (Dhania),1 tablespoon Amchur (Dry Mango Powder),Sunflower Oil - as required
# 5656
# Sentences:
# ...

# %%
# Training the Word2Vec model
model = Word2Vec(sentences, min_count=1)


words = model.wv.index_to_key

# %%
# Finding Word Vectors
vector = model.wv['salt']
print(vector)
print("No. of Dimension of the vector: ",len(vector))

# Most similar words
similar = model.wv.most_similar('salt')
print(similar)
# Out:
# [ 0.6712007   0.06638515 -0.45589682 -1.3678653  -0.9159873   0.00392277
#   0.13313144  0.8056117  -0.9893487  -0.80129987 -0.75434655 -0.71882254
#   0.13287024  0.513259   -1.0175766  -0.9351974  -0.15576     0.68108624
#  -0.41491225 -0.01153722 -0.5816099  -0.2852964   0.1978706   0.2722409
#  -0.26705563 -0.8808204   0.35312688  0.4685707  -0.17407799  0.6279131
#   0.51026756 -0.73047435 -0.74486977 -1.2246553   0.15034765  0.19904827
#   0.97835743  0.6141639   0.15651992  0.18403499 -0.22681695  0.9491851
#  -0.210584    0.32722986 -0.8845957   0.01379984 -0.50223124  0.18745835
#  -0.5420107   0.5926385  -0.53397995 -0.68545526  0.45632198 -0.29161298
#   0.04501118 -0.9041381   0.8697572  -1.1031743  -1.0518079  -0.11138523
#   0.08115093 -0.9155029   0.6817076   0.42525083 -0.08875129  0.04788892
#  -0.894915   -0.58268565  0.46826452 -0.5971798   1.1730081   0.5683171
#   0.90817845  0.6440192   0.9532827  -0.2546306  -0.36486766  0.65973735
# ...
